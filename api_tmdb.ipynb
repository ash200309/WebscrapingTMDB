# %%
import pandas as pd 
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/tv/top_rated"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlN2ExNjAwMjBkMTljODdmNWIxNmZjOTE5Mzg1NGFjNSIsInN1YiI6IjYzZTI3ODQyNzczOTQxMDBlOTEwOTM1ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.pnbxWP7z3_i8RIm0rG_4TPF39ffXvNvqoIIIqpOolSA"
}

response = requests.get(url, headers=headers)

print(response)
# Out:
# <Response [200]>

# %%
response = requests.get('https://api.themoviedb.org/3/tv/top_rated?api_key=e7a160020d19c87f5b16fc9193854ac5&language=en-US&page=1')
pd.DataFrame(response.json()["results"])
# Out:
#                        backdrop_path first_air_date  \
# 0   /84XPpjGvxNyExjSuLQe0SzioErt.jpg     2008-01-20
# 1   /rkB4LyZHo1NHXFEDHl9vSD9r1lI.jpg     2021-11-06
# 2   /a6ptrTUH1c5OdWanjyYtAkOuYD0.jpg     1999-10-20
# 3   /uGy4DCmM33I7l86W7iCskNkvmLD.jpg     2013-12-02
# 4   /70YdbMELM4b8x8VXjlubymb2bQ0.jpg     2017-03-19
# 5   /lY12qhlsm9JJ3I2PyAZNkpU9a5h.jpg     2009-04-05
# 6   /kU98MbVVgi72wzceyrEbClZmMFe.jpg     2005-02-21
# 7   /6UH52Fmau8RPsMAbQbjwN3wJSCj.jpg     2021-03-25
# 8   /smSbK5cd8T9XHcxEUcems23BDEF.jpg     2016-12-02
# 9   /uDgy6hyPd82kOHh6I95FLtLnj6p.jpg     2023-01-15
# 10  /nTvM4mhqNlHIvUkI1gVnW6XP7GG.jpg     2019-04-06
# 11  /2vbE9ajftJ7dkqUAyxDS0WFILx8.jpg     2010-09-06
# 12  /jsXKG9uppnPrhqFNhImllyCfLhl.jpg     2016-04-03
# 13  /cHyY5z4txdVyGtYMvBJhCqCcJso.jpg     2020-01-10
# 14  /zbBNp4djy9dGOfMzVBQoP1ZAdET.jpg     2017-06-19
# 15  /pb8Z3Ef6CFjpm87hKW3DfdUge3J.jpg     2022-11-03
# 16  /nGfjgUlES2WuYrHXNNF4fbGe2Eq.jpg     2019-10-08
# ...

# %%
df_list = []  

for i in range(1, 148):
    response = requests.get('https://api.themoviedb.org/3/tv/top_rated?api_key=e7a160020d19c87f5b16fc9193854ac5&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])
    df_list.append(temp_df)  

df = pd.concat(df_list, ignore_index=True)

print(df)
# Out:
#                          backdrop_path first_air_date               genre_ids  \
# 0     /84XPpjGvxNyExjSuLQe0SzioErt.jpg     2008-01-20                [18, 80]
# 1     /rkB4LyZHo1NHXFEDHl9vSD9r1lI.jpg     2021-11-06  [16, 18, 10765, 10759]
# 2     /a6ptrTUH1c5OdWanjyYtAkOuYD0.jpg     1999-10-20         [10759, 35, 16]
# 3     /uGy4DCmM33I7l86W7iCskNkvmLD.jpg     2013-12-02  [16, 35, 10765, 10759]
# 4     /70YdbMELM4b8x8VXjlubymb2bQ0.jpg     2017-03-19             [18, 10751]
# ...                                ...            ...                     ...
# 2928  /2Ne8sYfnnRVl9BaghudN8bSkMnW.jpg     1997-03-31          [10751, 10762]
# 2929  /hUz0UHWSVd6e1g3I6vT4shAsnoY.jpg     1985-02-19         [10766, 18, 80]
# 2930  /lySfoBxAYuP5t2vxhKOvM0tpgEZ.jpg     2023-01-12                [16, 35]
# 2931  /2q4aPLPu7XqAbDe8JXcRyK5i6g9.jpg     2023-05-10                [99, 18]
# 2932                              None     2006-10-09                    [35]
#
# ...

# %%
tv_show_df=df.drop(columns=["backdrop_path","genre_ids","origin_country","original_language","poster_path"])

# %%
tv_show_df.to_csv("TBMD_TV_SHOWS",index=False)

# %%
tv_show_df
# Out:
#      first_air_date      id             name    original_name  \
# 0        2008-01-20    1396     Breaking Bad     Breaking Bad
# 1        2021-11-06   94605           Arcane           Arcane
# 2        1999-10-20   37854        One Piece            ワンピース
# 3        2013-12-02   60625   Rick and Morty   Rick and Morty
# 4        2017-03-19   70785   Anne with an E   Anne with an E
# ...             ...     ...              ...              ...
# 2928     1997-03-31    1682      Teletubbies      Teletubbies
# 2929     1985-02-19    1871       EastEnders       EastEnders
# 2930     2023-01-12  126725            Velma            Velma
# 2931     2023-05-10  224387  Queen Cleopatra  Queen Cleopatra
# 2932     2006-10-09       5           La Job           La Job
#
#                                                overview  popularity  \
# 0     When Walter White, a New Mexico chemistry teac...     352.010
# 1     Amid the stark discord of twin cities Piltover...      54.231
# ...
